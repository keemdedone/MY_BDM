# /kaggle/input/bdm-2021-face/622110206_1_0.jpg
# /kaggle/input/bdm-2021-face/612110186_3_1.jpg
# /kaggle/input/bdm-2021-face/622110225_3_0.jpg
# /kaggle/input/bdm-2021-face/622110207_3_0.jpg
# /kaggle/input/bdm-2021-face/622110172_4_0.jpg
# /kaggle/input/bdm-2021-face/612110234_2_0.jpg
# /kaggle/input/bdm-2021-face/612110234_3_0.jpg
# /kaggle/input/bdm-2021-face/612110174_3_0.jpg
# /kaggle/input/bdm-2021-face/622110222_3_1.jpg
# /kaggle/input/bdm-2021-face/622110225_2_0.jpg
# /kaggle/input/bdm-2021-face/602110108_2_0.jpg
# /kaggle/input/bdm-2021-face/622110154_4_0.jpg
# /kaggle/input/bdm-2021-face/622110222_1_1.jpg
# /kaggle/input/bdm-2021-face/622110210_4_0.jpg
# /kaggle/input/bdm-2021-face/622110206_3_0.jpg
# /kaggle/input/bdm-2021-face/612110165_4_0.jpg
# /kaggle/input/bdm-2021-face/622110240_3_0.jpg
# /kaggle/input/bdm-2021-face/612110186_4_1.jpg
# /kaggle/input/bdm-2021-face/622110210_3_0.jpg
# /kaggle/input/bdm-2021-face/612110159_4_0.jpg
# /kaggle/input/bdm-2021-face/622110225_4_0.jpg
# /kaggle/input/bdm-2021-face/612110165_2_0.jpg
# /kaggle/input/bdm-2021-face/622110240_2_0.jpg
# /kaggle/input/bdm-2021-face/612110159_1_0.jpg
# /kaggle/input/bdm-2021-face/622110172_2_0.jpg
# /kaggle/input/bdm-2021-face/622110206_2_0.jpg
# /kaggle/input/bdm-2021-face/612110174_2_0.jpg
# /kaggle/input/bdm-2021-face/622110209_2_1.jpg

# %%
import time
import sys
from time import sleep
from tqdm.notebook import tqdm

# %%
import glob
filename = glob.glob("/kaggle/input/bdm-2021-face/*.*")
filename[0].split("_")
# Out:
# ['/kaggle/input/bdm-2021-face/622110140', '4', '0.jpg']

# %%
label = np.array([float(item.split("_")[-1].split(".")[0]) for item in filename])
sum(label==1)
# Out:
# 20

# %%
# !mkdir train
# !mkdir train/male
# !mkdir train/female

# %%
import shutil 
for i in range(len(label)):
    if label[i] == 0:
        shutil.copy(filename[i], '/kaggle/working/train/male/')
    else:
        shutil.copy(filename[i], '/kaggle/working/train/female/')

# %%
# !mkdir test
# !mkdir test/male
# !mkdir test/female

# %%
import glob
filemale = glob.glob("./train/male/*.*")
filefemale = glob.glob("./train/female/*.*")

# %%
midx = np.random.randint(len(filemale), size = 4)
fidx = np.random.randint(len(filefemale), size = 2)

# %%
for i in fidx:
   shutil.move(filefemale[i],'./test/female/')
for i in midx:
    shutil.move(filemale[i],'./test/male/')

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
data_generator = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        #rescale = 1.0/255.0,   # Intensity Normalized
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.2, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False,   # randomly flip images
        validation_split=0.2)
# Out:
# 2021-09-14 11:38:06.604552: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-09-14 11:38:06.604697: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
train_dir = './train'
batch_size = 8
img_height = 100 
img_width  = 100
train_generator = data_generator.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size= batch_size,
    class_mode='binary',
    subset='training') # set as training data

validation_generator = data_generator.flow_from_directory(
    train_dir, # same directory as training data
    target_size=(img_height, img_width),
    batch_size= batch_size,
    class_mode='binary',
    subset='validation') # set as validation data
# Out:
# Found 63 images belonging to 2 classes.
# Found 15 images belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
# preparing the layers in the Convolutional Deep Neural Network
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph() # Clear Model
    model = Sequential()
    model.add(Conv2D(filters = 32, kernel_size = (3, 3), activation = 'relu', input_shape = train_generator.image_shape))
    model.add(Conv2D(filters = 16, kernel_size = (3, 3), activation = 'relu'))
    model.add(Conv2D(filters = 8, kernel_size = (3, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Flatten())
    model.add(Dense(units = 64, activation = 'relu'))
    model.add(Dense(units = 32, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 16, activation = 'relu'))
    model.add(Dropout(rate = 0.1))
    model.add(Dense(units = 8, activation = 'relu'))
    model.add(Dense(units = 1, activation = 'sigmoid'))
    model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = create_model()
epochs_ = 50
fitted_model = model.fit_generator(
        train_generator,
        steps_per_epoch = train_generator.samples // batch_size,
        validation_data = validation_generator, 
        validation_steps = validation_generator.samples // batch_size,
        epochs = epochs_)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 7s 909ms/step - loss: 3.2378 - accuracy: 0.6548 - val_loss: 0.8230 - val_accuracy: 0.6250
# Epoch 2/50
# 7/7 [==============================] - 6s 869ms/step - loss: 0.4487 - accuracy: 0.8050 - val_loss: 0.6590 - val_accuracy: 0.7500
# Epoch 3/50
# 7/7 [==============================] - 6s 855ms/step - loss: 0.6228 - accuracy: 0.7392 - val_loss: 0.6775 - val_accuracy: 0.7500
# Epoch 4/50
# 7/7 [==============================] - 5s 804ms/step - loss: 0.5909 - accuracy: 0.7810 - val_loss: 0.7988 - val_accuracy: 0.6250
# Epoch 5/50
# 7/7 [==============================] - 6s 763ms/step - loss: 0.5212 - accuracy: 0.8277 - val_loss: 0.3719 - val_accuracy: 0.8750
# Epoch 6/50
# 7/7 [==============================] - 6s 808ms/step - loss: 0.4458 - accuracy: 0.8371 - val_loss: 0.6628 - val_accuracy: 0.8750
# Epoch 7/50
# 7/7 [==============================] - 6s 708ms/step - loss: 0.5381 - accuracy: 0.7813 - val_loss: 0.5409 - val_accuracy: 0.7500
# Epoch 8/50
# 7/7 [==============================] - 6s 855ms/step - loss: 0.5562 - accuracy: 0.7062 - val_loss: 0.5708 - val_accuracy: 0.7500
# Epoch 9/50
# 7/7 [==============================] - 6s 798ms/step - loss: 0.5875 - accuracy: 0.6711 - val_loss: 0.3577 - val_accuracy: 1.0000
# Epoch 10/50
# 7/7 [==============================] - 6s 860ms/step - loss: 0.5867 - accuracy: 0.8001 - val_loss: 0.4053 - val_accuracy: 0.7500
# Epoch 11/50
# 7/7 [==============================] - 6s 879ms/step - loss: 0.3871 - accuracy: 0.7906 - val_loss: 0.4014 - val_accuracy: 0.8750
# Epoch 12/50
# 7/7 [==============================] - 6s 797ms/step - loss: 0.4066 - accuracy: 0.7829 - val_loss: 0.5046 - val_accuracy: 0.7500
# Epoch 13/50
# 7/7 [==============================] - 6s 813ms/step - loss: 0.4146 - accuracy: 0.7020 - val_loss: 0.8624 - val_accuracy: 0.6250
# Epoch 14/50
# 7/7 [==============================] - 6s 836ms/step - loss: 0.3763 - accuracy: 0.7440 - val_loss: 0.4064 - val_accuracy: 0.7500
# Epoch 15/50
# 7/7 [==============================] - 5s 800ms/step - loss: 0.2967 - accuracy: 0.8640 - val_loss: 0.3126 - val_accuracy: 0.7500
# Epoch 16/50
# 7/7 [==============================] - 6s 810ms/step - loss: 0.2966 - accuracy: 0.8686 - val_loss: 0.5303 - val_accuracy: 0.7500
# Epoch 17/50
# 7/7 [==============================] - 6s 894ms/step - loss: 0.2810 - accuracy: 0.8679 - val_loss: 0.2456 - val_accuracy: 0.8750
# Epoch 18/50
# 7/7 [==============================] - 6s 864ms/step - loss: 0.2868 - accuracy: 0.8329 - val_loss: 0.2306 - val_accuracy: 1.0000
# Epoch 19/50
# 7/7 [==============================] - 6s 856ms/step - loss: 0.2379 - accuracy: 0.8558 - val_loss: 0.2810 - val_accuracy: 0.8750
# Epoch 20/50
# 7/7 [==============================] - 6s 866ms/step - loss: 0.1951 - accuracy: 0.9363 - val_loss: 0.2705 - val_accuracy: 1.0000
# Epoch 21/50
# 7/7 [==============================] - 6s 746ms/step - loss: 0.3128 - accuracy: 0.8177 - val_loss: 0.3922 - val_accuracy: 0.8750
# Epoch 22/50
# 7/7 [==============================] - 6s 805ms/step - loss: 0.2412 - accuracy: 0.9001 - val_loss: 0.3024 - val_accuracy: 0.8750
# Epoch 23/50
# 7/7 [==============================] - 6s 919ms/step - loss: 0.2886 - accuracy: 0.8965 - val_loss: 0.1697 - val_accuracy: 1.0000
# Epoch 24/50
# 7/7 [==============================] - 6s 948ms/step - loss: 0.2890 - accuracy: 0.8686 - val_loss: 1.1815 - val_accuracy: 0.8750
# Epoch 25/50
# 7/7 [==============================] - 6s 832ms/step - loss: 0.2283 - accuracy: 0.9272 - val_loss: 0.4554 - val_accuracy: 0.7500
# Epoch 26/50
# 7/7 [==============================] - 6s 879ms/step - loss: 0.4339 - accuracy: 0.8386 - val_loss: 0.5754 - val_accuracy: 0.5000
# Epoch 27/50
# 7/7 [==============================] - 6s 862ms/step - loss: 0.2443 - accuracy: 0.8952 - val_loss: 0.1242 - val_accuracy: 1.0000
# Epoch 28/50
# 7/7 [==============================] - 6s 798ms/step - loss: 0.2790 - accuracy: 0.8432 - val_loss: 0.4994 - val_accuracy: 0.7500
# Epoch 29/50
# 7/7 [==============================] - 6s 865ms/step - loss: 0.1893 - accuracy: 0.9050 - val_loss: 0.3340 - val_accuracy: 0.7500
# Epoch 30/50
# 7/7 [==============================] - 6s 721ms/step - loss: 0.2660 - accuracy: 0.8852 - val_loss: 0.0350 - val_accuracy: 1.0000
# Epoch 31/50
# 7/7 [==============================] - 6s 813ms/step - loss: 0.4980 - accuracy: 0.8130 - val_loss: 0.2089 - val_accuracy: 1.0000
# Epoch 32/50
# 7/7 [==============================] - 6s 878ms/step - loss: 0.2731 - accuracy: 0.9254 - val_loss: 0.2900 - val_accuracy: 0.8750
# Epoch 33/50
# 7/7 [==============================] - 6s 833ms/step - loss: 0.2445 - accuracy: 0.9279 - val_loss: 0.5414 - val_accuracy: 0.7500
# Epoch 34/50
# 7/7 [==============================] - 6s 800ms/step - loss: 0.1970 - accuracy: 0.9409 - val_loss: 0.2112 - val_accuracy: 0.8750
# Epoch 35/50
# 7/7 [==============================] - 6s 735ms/step - loss: 0.1741 - accuracy: 0.9240 - val_loss: 0.2492 - val_accuracy: 0.8750
# Epoch 36/50
# 7/7 [==============================] - 6s 808ms/step - loss: 0.0893 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.8750
# Epoch 37/50
# 7/7 [==============================] - 6s 861ms/step - loss: 0.1492 - accuracy: 0.9580 - val_loss: 0.4770 - val_accuracy: 0.7500
# Epoch 38/50
# 7/7 [==============================] - 6s 683ms/step - loss: 0.1491 - accuracy: 0.9609 - val_loss: 0.7294 - val_accuracy: 0.7500
# Epoch 39/50
# 7/7 [==============================] - 5s 828ms/step - loss: 0.1398 - accuracy: 0.9826 - val_loss: 0.4519 - val_accuracy: 0.6250
# Epoch 40/50
# 7/7 [==============================] - 6s 874ms/step - loss: 0.2226 - accuracy: 0.9528 - val_loss: 0.2633 - val_accuracy: 0.8750
# Epoch 41/50
# 7/7 [==============================] - 6s 822ms/step - loss: 0.1040 - accuracy: 0.9778 - val_loss: 0.2977 - val_accuracy: 0.8750
# Epoch 42/50
# 7/7 [==============================] - 6s 878ms/step - loss: 0.1731 - accuracy: 0.9697 - val_loss: 0.2480 - val_accuracy: 0.8750
# Epoch 43/50
# 7/7 [==============================] - 5s 699ms/step - loss: 0.0818 - accuracy: 1.0000 - val_loss: 0.7908 - val_accuracy: 0.7500
# Epoch 44/50
# 7/7 [==============================] - 6s 834ms/step - loss: 0.2425 - accuracy: 0.9308 - val_loss: 0.0946 - val_accuracy: 1.0000
# Epoch 45/50
# 7/7 [==============================] - 6s 846ms/step - loss: 0.1043 - accuracy: 0.9715 - val_loss: 0.1907 - val_accuracy: 1.0000
# Epoch 46/50
# 7/7 [==============================] - 6s 879ms/step - loss: 0.1673 - accuracy: 0.8907 - val_loss: 0.6875 - val_accuracy: 0.8750
# Epoch 47/50
# 7/7 [==============================] - 6s 796ms/step - loss: 0.0652 - accuracy: 1.0000 - val_loss: 1.5688 - val_accuracy: 0.7500
# Epoch 48/50
# 7/7 [==============================] - 6s 827ms/step - loss: 0.2630 - accuracy: 0.9607 - val_loss: 0.6617 - val_accuracy: 0.7500
# Epoch 49/50
# 7/7 [==============================] - 6s 865ms/step - loss: 0.7040 - accuracy: 0.8067 - val_loss: 0.6509 - val_accuracy: 0.5000
# Epoch 50/50
# 7/7 [==============================] - 6s 815ms/step - loss: 0.3553 - accuracy: 0.8641 - val_loss: 1.1197 - val_accuracy: 0.2500

# %%
import glob
filefemale = glob.glob("./test/female/*.*")
filemale = glob.glob("./test/male/*.*")

# %%
from tensorflow.keras.preprocessing import image
# testing the model
plabel = []
for filename in filefemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==0)/len(plabel)
# Out:
# 1.0

# %%
plabel = []
for filename in filemale:
    test_image = image.load_img(filename, target_size = (img_height, img_width))
    test_image = image.img_to_array(test_image)
    test_image = np.expand_dims(test_image, axis = 0)
    plabel.append(np.round(model.predict(test_image)[0][0]))
plabel = np.array(plabel)
sum(plabel==1)/len(plabel)
# Out:
# 1.0
