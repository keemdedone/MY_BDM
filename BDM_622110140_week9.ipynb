# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-approval-prediction/credit_record.csv
# /kaggle/input/credit-card-approval-prediction/application_record.csv

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv')

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.dtypes
# Out:
# ID                       int64
# CODE_GENDER             object
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_BIRTH               int64
# DAYS_EMPLOYED            int64
# FLAG_MOBIL               int64
# FLAG_WORK_PHONE          int64
# FLAG_PHONE               int64
# FLAG_EMAIL               int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean = df.dropna(axis=0)
df_clean.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE        False
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df_clean =  df_clean.drop(['CODE_GENDER','DAYS_BIRTH','FLAG_EMAIL','FLAG_WORK_PHONE','FLAG_PHONE','FLAG_MOBIL'],axis=1)

# %%
df_clean.any()
# Out:
# ID                     True
# FLAG_OWN_CAR           True
# FLAG_OWN_REALTY        True
# CNT_CHILDREN           True
# AMT_INCOME_TOTAL       True
# NAME_INCOME_TYPE       True
# NAME_EDUCATION_TYPE    True
# NAME_FAMILY_STATUS     True
# NAME_HOUSING_TYPE      True
# DAYS_EMPLOYED          True
# OCCUPATION_TYPE        True
# CNT_FAM_MEMBERS        True
# dtype: bool

# %%
df_clean.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean['FLAG_OWN_CAR'] = pd.factorize(df_clean['FLAG_OWN_CAR'])[0]
df_clean['FLAG_OWN_REALTY'] = pd.factorize(df_clean['FLAG_OWN_REALTY'])[0]
df_clean['NAME_INCOME_TYPE'] = pd.factorize(df_clean['NAME_INCOME_TYPE'])[0]
df_clean['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean['NAME_EDUCATION_TYPE'])[0]
df_clean['NAME_FAMILY_STATUS'] = pd.factorize(df_clean['NAME_FAMILY_STATUS'])[0]
df_clean['NAME_HOUSING_TYPE'] = pd.factorize(df_clean['NAME_HOUSING_TYPE'])[0]
df_clean['OCCUPATION_TYPE'] = pd.factorize(df_clean['OCCUPATION_TYPE'])[0]

# %%
X = df_clean.values
X.shape
# Out:
# (304354, 12)

# %%
df_label = pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv')

# %%
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label.isnull().any()
# Out:
# ID                False
# MONTHS_BALANCE    False
# STATUS            False
# dtype: bool

# %%
df_label.dtypes
# Out:
# ID                 int64
# MONTHS_BALANCE     int64
# STATUS            object
# dtype: object

# %%
df_label['STATUS'].unique()
# Out:
# array(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype=object)

# %%
df_label['STATUS'] = pd.factorize(df_label['STATUS'])[0]

# %%
df_label_clean = df_label[df_label['STATUS'] != 0 ]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2 ] = 10
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_clean['STATUS'][df_label['STATUS'] <= 2 ] = 0
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py:992: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._where(~key, value, inplace=True)

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
df_label_group
# Out:
#          MONTHS_BALANCE  STATUS
# ID
# 5001711       -2.000000     0.0
# 5001712       -9.000000     0.0
# 5001717      -10.500000     0.0
# 5001718      -18.724138     1.0
# 5001719      -21.000000     0.0
# ...                 ...     ...
# 5150480      -36.500000     0.0
# 5150482      -19.500000     0.0
# 5150484       -6.000000     0.0
# 5150485       -0.500000     0.0
# 5150487      -14.500000     0.0
#
# [41449 rows x 2 columns]

# %%
client_id = df_label_group.index.values
client_label = df_label_group['STATUS'].values

# %%
df_clean.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR             int64
# FLAG_OWN_REALTY          int64
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE         int64
# NAME_EDUCATION_TYPE      int64
# NAME_FAMILY_STATUS       int64
# NAME_HOUSING_TYPE        int64
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE          int64
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
X_clien_id = df_clean['ID'].values
df_clean =  df_clean.drop(['ID'],axis=1)

# %%
X = df_clean.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id = [item for item in X_clien_id if item in client_id]

# %%
y = np.array([client_label[np.where(client_id == item)][0] for item in real_client_id])

# %%
X_final = [X[np.where(X_clien_id == item), :][0] for item in real_client_id]

# %%
X_real_final = np.vstack(X_final)

# %%
X_real_final.shape
# Out:
# (22737, 11)

# %%
len(y)
# Out:
# 22737

# %%
sum(y==0)
# Out:
# 19648

# %%
sum(y==1)
# Out:
# 3089

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=1)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
from sklearn.model_selection import train_test_split #มีข้อมูล 2 set
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %%
import time
import sys
from time import sleep
from tqdm.notebook import tqdm
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import ExtraTreesClassifier

t0 = time.time()
pr = {
    'n_estimators' : [10,50,100,200,300,500],
    'min_samples_leaf' : [1,2,4,8,16,32,64],
}

for i in tqdm(pr):
    best_clf = RandomizedSearchCV(ExtraTreesClassifier(random_state=0),pr,cv=10,scoring='accuracy',n_iter=5,random_state=0) 
    best_clf.fit(X_train_norm, y_train)
print ("Training time: " + str(round(time.time()-t0,2)) + " s")
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Training time: 61.96 s

# %%
yp = best_clf.predict(X_test_norm)
acc_test = sum(yp == y_test)/len(y_test)
print("Best score is " + str(best_clf.best_score_*100) +('\n') +"Best param is " + str(best_clf.best_params_))
print("Test Training Acc. : " + str(acc_test*100))
# Out:
# Best score is 63.015279376038855
# Best param is {'n_estimators': 300, 'min_samples_leaf': 1}
# Test Training Acc. : 67.63754045307444

# %%
import tensorflow as tf

# %%
tf.compat.v1.reset_default_graph() # Clear Model
np.random.seed(1) # Fix Randomness
tf.compat.v1.random.set_random_seed(1) # Fix Randomness

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(250, activation='relu', input_shape=(11,)),
  tf.keras.layers.Dense(150, activation='relu'),
  tf.keras.layers.Dense(100, activation='relu'),
  tf.keras.layers.Dense(50, activation='relu'),
  tf.keras.layers.Dense(25, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')    
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 250)               3000
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               37650
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               15100
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_4 (Dense)              (None, 25)                1275
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 62,101
# Trainable params: 62,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
import sys

train_acc = list()
val_acc = list()
t0 = time.time()
for i in tqdm(range(0,250)):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
print ("Running time: " + str(round(time.time()-t0,2)) + " s")
# Out:
#   0%|          | 0/250 [00:00<?, ?it/s]
# 20/20 [==============================] - 2s 41ms/step - loss: 0.6937 - accuracy: 0.5040 - val_loss: 0.6935 - val_accuracy: 0.5137
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6895 - accuracy: 0.5363 - val_loss: 0.6961 - val_accuracy: 0.5157
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6889 - accuracy: 0.5378 - val_loss: 0.6953 - val_accuracy: 0.5217
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6872 - accuracy: 0.5472 - val_loss: 0.6963 - val_accuracy: 0.5248
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6858 - accuracy: 0.5570 - val_loss: 0.6952 - val_accuracy: 0.5410
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6840 - accuracy: 0.5560 - val_loss: 0.6956 - val_accuracy: 0.5450
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6828 - accuracy: 0.5578 - val_loss: 0.6935 - val_accuracy: 0.5490
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6792 - accuracy: 0.5692 - val_loss: 0.6948 - val_accuracy: 0.5440
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6763 - accuracy: 0.5684 - val_loss: 0.6953 - val_accuracy: 0.5389
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6733 - accuracy: 0.5745 - val_loss: 0.6954 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6702 - accuracy: 0.5722 - val_loss: 0.7006 - val_accuracy: 0.5308
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6678 - accuracy: 0.5818 - val_loss: 0.6988 - val_accuracy: 0.5450
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6638 - accuracy: 0.5846 - val_loss: 0.7018 - val_accuracy: 0.5440
# 20/20 [==============================] - 0s 13ms/step - loss: 0.6604 - accuracy: 0.5899 - val_loss: 0.6995 - val_accuracy: 0.5288
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6563 - accuracy: 0.6008 - val_loss: 0.7034 - val_accuracy: 0.5308
# 20/20 [==============================] - 0s 14ms/step - loss: 0.6529 - accuracy: 0.6066 - val_loss: 0.7035 - val_accuracy: 0.5207
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6483 - accuracy: 0.6036 - val_loss: 0.7114 - val_accuracy: 0.5177
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4042 - accuracy: 0.7959 - val_loss: 1.0830 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4014 - accuracy: 0.7933 - val_loss: 1.0999 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 14ms/step - loss: 0.4023 - accuracy: 0.7923 - val_loss: 1.1058 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4019 - accuracy: 0.7870 - val_loss: 1.1391 - val_accuracy: 0.6067
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4009 - accuracy: 0.7855 - val_loss: 1.1589 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4061 - accuracy: 0.7888 - val_loss: 1.1783 - val_accuracy: 0.5875
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4107 - accuracy: 0.7855 - val_loss: 1.2117 - val_accuracy: 0.5854
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4173 - accuracy: 0.7855 - val_loss: 1.2561 - val_accuracy: 0.5885
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4274 - accuracy: 0.7769 - val_loss: 1.2523 - val_accuracy: 0.5824
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4207 - accuracy: 0.7827 - val_loss: 1.2006 - val_accuracy: 0.5905
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4139 - accuracy: 0.7847 - val_loss: 1.2208 - val_accuracy: 0.5956
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4087 - accuracy: 0.7910 - val_loss: 1.2250 - val_accuracy: 0.6047
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4020 - accuracy: 0.7938 - val_loss: 1.2038 - val_accuracy: 0.6097
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3949 - accuracy: 0.7996 - val_loss: 1.1725 - val_accuracy: 0.6077
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3915 - accuracy: 0.8034 - val_loss: 1.1913 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3895 - accuracy: 0.7994 - val_loss: 1.2142 - val_accuracy: 0.5996
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3904 - accuracy: 0.7991 - val_loss: 1.1831 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3895 - accuracy: 0.7989 - val_loss: 1.1897 - val_accuracy: 0.6016
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3924 - accuracy: 0.7976 - val_loss: 1.1905 - val_accuracy: 0.6026
# 20/20 [==============================] - 1s 34ms/step - loss: 0.3967 - accuracy: 0.7956 - val_loss: 1.1809 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3979 - accuracy: 0.7964 - val_loss: 1.1984 - val_accuracy: 0.6158
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3989 - accuracy: 0.7979 - val_loss: 1.1787 - val_accuracy: 0.6148
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4006 - accuracy: 0.7976 - val_loss: 1.1871 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3986 - accuracy: 0.7961 - val_loss: 1.1845 - val_accuracy: 0.6006
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3950 - accuracy: 0.7890 - val_loss: 1.1965 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3979 - accuracy: 0.7878 - val_loss: 1.1985 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3984 - accuracy: 0.7953 - val_loss: 1.1761 - val_accuracy: 0.6188
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3925 - accuracy: 0.7956 - val_loss: 1.2203 - val_accuracy: 0.6097
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3989 - accuracy: 0.8012 - val_loss: 1.2235 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3926 - accuracy: 0.8032 - val_loss: 1.2641 - val_accuracy: 0.6117
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3920 - accuracy: 0.8037 - val_loss: 1.2364 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 15ms/step - loss: 0.3972 - accuracy: 0.7971 - val_loss: 1.1886 - val_accuracy: 0.6087
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3913 - accuracy: 0.7951 - val_loss: 1.2124 - val_accuracy: 0.6188
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3876 - accuracy: 0.8050 - val_loss: 1.2723 - val_accuracy: 0.6138
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3897 - accuracy: 0.8019 - val_loss: 1.2495 - val_accuracy: 0.6077
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3992 - accuracy: 0.7969 - val_loss: 1.1761 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4082 - accuracy: 0.7898 - val_loss: 1.1163 - val_accuracy: 0.6026
# 20/20 [==============================] - 0s 13ms/step - loss: 0.4081 - accuracy: 0.7835 - val_loss: 1.1651 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 12ms/step - loss: 0.4051 - accuracy: 0.7931 - val_loss: 1.1243 - val_accuracy: 0.6016
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3881 - accuracy: 0.8004 - val_loss: 1.1035 - val_accuracy: 0.6138
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3724 - accuracy: 0.8093 - val_loss: 1.1807 - val_accuracy: 0.6239
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3613 - accuracy: 0.8153 - val_loss: 1.2026 - val_accuracy: 0.6148
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3477 - accuracy: 0.8242 - val_loss: 1.2259 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3491 - accuracy: 0.8244 - val_loss: 1.2396 - val_accuracy: 0.6269
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3421 - accuracy: 0.8242 - val_loss: 1.2573 - val_accuracy: 0.6289
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3395 - accuracy: 0.8260 - val_loss: 1.2782 - val_accuracy: 0.6239
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3375 - accuracy: 0.8275 - val_loss: 1.2900 - val_accuracy: 0.6289
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3349 - accuracy: 0.8295 - val_loss: 1.3296 - val_accuracy: 0.6400
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3370 - accuracy: 0.8285 - val_loss: 1.3571 - val_accuracy: 0.6320
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3384 - accuracy: 0.8209 - val_loss: 1.3803 - val_accuracy: 0.6239
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3399 - accuracy: 0.8249 - val_loss: 1.3742 - val_accuracy: 0.6249
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3430 - accuracy: 0.8252 - val_loss: 1.3682 - val_accuracy: 0.6218
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3420 - accuracy: 0.8265 - val_loss: 1.3564 - val_accuracy: 0.6198
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3478 - accuracy: 0.8244 - val_loss: 1.3375 - val_accuracy: 0.6299
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3557 - accuracy: 0.8141 - val_loss: 1.3147 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 12ms/step - loss: 0.
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3205 - accuracy: 0.8391 - val_loss: 1.3822 - val_accuracy: 0.6350
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3250 - accuracy: 0.8310 - val_loss: 1.3535 - val_accuracy: 0.6380
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3260 - accuracy: 0.8305 - val_loss: 1.3554 - val_accuracy: 0.6208
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3278 - accuracy: 0.8348 - val_loss: 1.4092 - val_accuracy: 0.6229
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3261 - accuracy: 0.8292 - val_loss: 1.4061 - val_accuracy: 0.6279
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3276 - accuracy: 0.8313 - val_loss: 1.4132 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3179 - accuracy: 0.8356 - val_loss: 1.3752 - val_accuracy: 0.6138
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3112 - accuracy: 0.8462 - val_loss: 1.3819 - val_accuracy: 0.6239
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3124 - accuracy: 0.8419 - val_loss: 1.4367 - val_accuracy: 0.6047
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3157 - accuracy: 0.8439 - val_loss: 1.4831 - val_accuracy: 0.6036
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3177 - accuracy: 0.8396 - val_loss: 1.4681 - val_accuracy: 0.5905
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3250 - accuracy: 0.8315 - val_loss: 1.4600 - val_accuracy: 0.6148
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3386 - accuracy: 0.8260 - val_loss: 1.4144 - val_accuracy: 0.6036
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3582 - accuracy: 0.8176 - val_loss: 1.4568 - val_accuracy: 0.5966
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3745 - accuracy: 0.8146 - val_loss: 1.4697 - val_accuracy: 0.6006
# 20/20 [==============================] - 0s 11ms/step - loss: 0.3861 - accuracy: 0.8014 - val_loss: 1.3307 - val_accuracy: 0.6168
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3687 - accuracy: 0.8156 - val_loss: 1.2574 - val_accuracy: 0.5986
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3618 - accuracy: 0.8143 - val_loss: 1.2877 - val_accuracy: 0.6239
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3424 - accuracy: 0.8227 - val_loss: 1.3187 - val_accuracy: 0.6279
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3203 - accuracy: 0.8363 - val_loss: 1.3453 - val_accuracy: 0.6289
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3116 - accuracy: 0.8432 - val_loss: 1.3717 - val_accuracy: 0.6360
# 20/20 [==============================] - 0s 14ms/step - loss: 0.3052 - accuracy: 0.8391 - val_loss: 1.4275 - val_accuracy: 0.6229
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2997 - accuracy: 0.8429 - val_loss: 1.4143 - val_accuracy: 0.6198
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2977 - accuracy: 0.8437 - val_loss: 1.4441 - val_accuracy: 0.6178
# 20/20 [==============================] - 0s 14ms/step - loss: 0.2990 - accuracy: 0.8447 - val_loss: 1.4388 - val_accuracy: 0.6249
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3031 - accuracy: 0.8444 - val_loss: 1.4357 - val_accuracy: 0.6229
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3084 - accuracy: 0.8399 - val_loss: 1.4538 - val_accuracy: 0.6269
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3120 - accuracy: 0.8401 - val_loss: 1.4467 - val_accuracy: 0.6269
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3098 - accuracy: 0.8394 - val_loss: 1.4396 - val_accuracy: 0.6330
# 20/20 [==============================] - 0s 12ms/step - loss: 0.3205 - accuracy: 0.8325 - val_loss: 1.4395 - val_accuracy: 0.6289
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3112 - accuracy: 0.8432 - val_loss: 1.3810 - val_accuracy: 0.6320
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2992 - accuracy: 0.8500 - val_loss: 1.4099 - val_accuracy: 0.6360
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2976 - accuracy: 0.8459 - val_loss: 1.4644 - val_accuracy: 0.6279
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2963 - accuracy: 0.8459 - val_loss: 1.4479 - val_accuracy: 0.6279
# 20/20 [==============================] - 0s 13ms/step - loss: 0.3003 - accuracy: 0.8437 - val_loss: 1.4390 - val_accuracy: 0.6289
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2956 - accuracy: 0.8480 - val_loss: 1.4462 - val_accuracy: 0.6269
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2925 - accuracy: 0.8475 - val_loss: 1.4568 - val_accuracy: 0.6299
# 20/20 [==============================] - 0s 11ms/step - loss: 0.2994 - accuracy: 0.8444 - val_loss: 1.4611 - val_accuracy: 0.6239
# 20/20 [==============================] - 0s 14ms/step - loss: 0.2913 - accuracy: 0.8510 - val_loss: 1.4925 - val_accuracy: 0.6350
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2895 - accuracy: 0.8470 - val_loss: 1.4806 - val_accuracy: 0.6340
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2847 - accuracy: 0.8528 - val_loss: 1.4622 - val_accuracy: 0.6421
# 20/20 [==============================] - 0s 12ms/step - loss: 0.2869 - accuracy: 0.8495 - val_loss: 1.4704 - val_accuracy: 0.6360
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2802 - accuracy: 0.8528 - val_loss: 1.4906 - val_accuracy: 0.6431
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2795 - accuracy: 0.8535 - val_loss: 1.4799 - val_accuracy: 0.6370
# 20/20 [==============================] - 0s 13ms/step - loss: 0.2752 - accuracy: 0.8571 - val_loss: 1.5133 - val_accuracy: 0.6380
# Running time: 77.76 s

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
plt.figure(num=None, figsize=(16, 8), dpi=90, facecolor='w', edgecolor='k')
plt.plot()
plt.plot(train_acc)
plt.plot(val_acc)
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# %%
y_predict = np.round(model.predict(X_test_norm))
y_predict = np.array([i[0] for i in y_predict.tolist()])
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 65.45307443365695
